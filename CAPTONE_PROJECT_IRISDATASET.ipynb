# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
iris_df = sns.load_dataset('iris')
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(f"Min of sepal_length : {np.min(iris_df.sepal_length)}")
print(f"Max of sepal_length : {np.max(iris_df.sepal_length)}")
print(f"Average of sepal_length : {np.average(iris_df.sepal_length)}")
print(f"Median of sepal_length : {np.median(iris_df.sepal_length)}")
print(f"Std of sepal_length : {np.std(iris_df.sepal_length)}")
# Out:
# Min of sepal_length : 4.3
# Max of sepal_length : 7.9
# Average of sepal_length : 5.843333333333334
# Median of sepal_length : 5.8
# Std of sepal_length : 0.8253012917851409

# %% [markdown]
# #### Species separately

# %%
setosa_df=iris_df[iris_df.species=='setosa']
versicolor_df=iris_df[iris_df.species=='versicolor']
virginica_df=iris_df[iris_df.species=='virginica']

# %%
print(f"Min of sepal_length in setosa: {np.min(setosa_df.sepal_length)}")
print(f"Max of sepal_length in setosa: {np.max(setosa_df.sepal_length)}")
print(f"Average of sepal_length in setosa : {np.average(setosa_df.sepal_length)}")
print(f"Median of sepal_length  in setosa: {np.median(setosa_df.sepal_length)}")
print(f"Std of sepal_length in setosa : {np.std(setosa_df.sepal_length)}")
# Out:
# Min of sepal_length in setosa: 4.3
# Max of sepal_length in setosa: 5.8
# Average of sepal_length in setosa : 5.006
# Median of sepal_length  in setosa: 5.0
# Std of sepal_length in setosa : 0.348946987377739

# %% [markdown]
# #### Special_value

# %%
def caculator(df):
    special_value=((df.sepal_length *df.sepal_width)-(df.petal_length **df.petal_width)) / (df.sepal_length + df.sepal_width + df.petal_length + df.petal_width)
    df["special_value"]=special_value
    return df

# %%
new_df=caculator(iris_df)
new_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      special_value
# 0         1.645136
# 1         1.434778
# 2         1.487886
# 3         1.401652
# 4         1.659842
# ...

# %% [markdown]
# # Visualization data with Matplotlib and Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
penguins_df = sns.load_dataset('penguins')
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins_df=penguins_df.dropna(axis=0)
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# ### Matplotlib

# %% [markdown]
# ##### PEAGUN FEATURE

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,15))
ax1.hist(penguins_df.bill_length_mm,label="nm",color="blue")
ax1.set_title('Penguins bill length')
ax1.set_xlabel('bill_length')
ax2.hist(penguins_df.bill_depth_mm,label="nm",color="green")
ax2.set_title('Penguins bill depth')
ax2.set_xlabel('bill_depth')
ax3.hist(penguins_df.flipper_length_mm,label="nm",color="red")
ax3.set_title('Penguins flipper length')
ax3.set_xlabel('flipper_length')
ax4.hist(penguins_df.body_mass_g,label="g",color="wheat")
ax4.set_title('Penguins body mass')
ax4.set_xlabel('body_mass')
fig.legend()

# %% [markdown]
# ##### The relationship in species, island and sex

# %%
species=set(penguins_df.species)
species
# Out:
# {'Adelie', 'Chinstrap', 'Gentoo'}

# %%
island=set(penguins_df.island)
island
# Out:
# {'Biscoe', 'Dream', 'Torgersen'}

# %%
sex=set(penguins_df.sex)
sex
# Out:
# {'Female', 'Male'}

# %%
fig,(ax1,ax2,ax3)=plt.subplots(nrows=3,ncols=1,figsize=(10,15))

#in species
gr_species1=penguins_df[penguins_df.species=='Adelie']
gr_species2=penguins_df[penguins_df.species=='Chinstrap']
gr_species3=penguins_df[penguins_df.species=='Gentoo']
ax1.scatter(gr_species1.bill_length_mm,gr_species1.bill_depth_mm,label='Adelie');
ax1.scatter(gr_species2.bill_length_mm,gr_species2.bill_depth_mm,label='Chinstrap');
ax1.scatter(gr_species3.bill_length_mm,gr_species3.bill_depth_mm,label='Gentoo');
ax1.set_xlabel('bill_length')
ax1.set_ylabel('bill_depth')
ax1.set_title('The relationship of the two features in species')
ax1.legend()

#in island
gr_island1=penguins_df[penguins_df.island=='Biscoe']
gr_island2=penguins_df[penguins_df.island=='Dream']
gr_island3=penguins_df[penguins_df.island=='Torgersen']
ax2.scatter(gr_island1.bill_length_mm,gr_island1.bill_depth_mm,label='Biscoe');
ax2.scatter(gr_island2.bill_length_mm,gr_island2.bill_depth_mm,label='Dream');
ax2.scatter(gr_island3.bill_length_mm,gr_island3.bill_depth_mm,label='Torgersen');
ax2.set_xlabel('bill_length')
ax2.set_ylabel('bill_depth')
ax2.set_title('The relationship of the two features in island')
ax2.legend()

#in sex
gr_sex1=penguins_df[penguins_df.sex=='Male']
gr_sex2=penguins_df[penguins_df.sex=='Female']
ax3.scatter(gr_sex1.bill_length_mm,gr_sex1.bill_depth_mm,label='Male');
ax3.scatter(gr_sex2.bill_length_mm,gr_sex2.bill_depth_mm,label='Female');
ax3.set_xlabel('bill_length')
ax3.set_ylabel('bill_depth')
ax3.set_title('The relationship of the two features in sex')
ax3.legend()

# %% [markdown]
# ##### The average value of each penguins feature in species , island and sex

# %%
gr_species=penguins_df.groupby(by='species').agg({'bill_length_mm':np.average,'bill_depth_mm':np.average,'flipper_length_mm':np.average,'body_mass_g':np.average}).reset_index()
gr_species
# Out:
#      species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0     Adelie       38.823973      18.347260         190.102740  3706.164384
# 1  Chinstrap       48.833824      18.420588         195.823529  3733.088235
# 2     Gentoo       47.568067      14.996639         217.235294  5092.436975

# %%
gr_island=penguins_df.groupby(by='island').agg({'bill_length_mm':np.average,'bill_depth_mm':np.average,'flipper_length_mm':np.average,'body_mass_g':np.average}).reset_index()
gr_island
# Out:
#       island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0     Biscoe       45.248466      15.907362         209.558282  4719.171779
# 1      Dream       44.221951      18.339837         193.186992  3718.902439
# 2  Torgersen       39.038298      18.451064         191.531915  3708.510638

# %%
gr_sex=penguins_df.groupby(by='sex').agg({'bill_length_mm':np.average,'bill_depth_mm':np.average,'flipper_length_mm':np.average,'body_mass_g':np.average}).reset_index()
gr_sex
# Out:
#       sex  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0  Female       42.096970      16.425455         197.363636  3862.272727
# 1    Male       45.854762      17.891071         204.505952  4545.684524

# %%
X_axis = np.arange(3)
width=0.1

plt.bar(X_axis,gr_species.bill_length_mm,width,label='bill_length')
plt.bar(X_axis+width,gr_species.bill_depth_mm,width,label='bill_depth')
plt.bar(X_axis+width*2,gr_species.flipper_length_mm,width,label='flipper_length')
plt.bar(X_axis+width*3,gr_species.body_mass_g,width,label='body_mass')

plt.xlabel('species')
plt.xticks(X_axis+width, gr_species.species)
plt.title('The average value of each penguins feature in species')
plt.legend()
plt.show()

# %%
X_axis = np.arange(len(gr_island.island))
width=0.1

plt.bar(X_axis,gr_island.bill_length_mm,width,label='bill_length')
plt.bar(X_axis+width,gr_island.bill_depth_mm,width,label='bill_depth')
plt.bar(X_axis+width*2,gr_island.flipper_length_mm,width,label='flipper_length')
plt.bar(X_axis+width*3,gr_island.body_mass_g,width,label='body_mass')

plt.xlabel('island')
plt.xticks(X_axis+width, gr_island.island)
plt.title('The average value of each penguins feature in species')
plt.legend()
plt.show()

# %%
X_axis = np.arange(len(gr_sex.sex))
width=0.1

plt.bar(X_axis,gr_sex.bill_length_mm,width,label='bill_length')
plt.bar(X_axis+width,gr_sex.bill_depth_mm,width,label='bill_depth')
plt.bar(X_axis+width*2,gr_sex.flipper_length_mm,width,label='flipper_length')
plt.bar(X_axis+width*3,gr_sex.body_mass_g,width,label='body_mass')

plt.xlabel('sex')
plt.xticks(X_axis+width,gr_sex.sex)
plt.title('The average value of each penguins feature in sex')
plt.legend()
plt.show()

# %% [markdown]
# ## Seaborn

# %% [markdown]
# ##### PEAGUN FEATURE

# %%
sns.histplot(x='bill_length_mm', kde=True, data=penguins_df,label='bill_length')
plt.title('Penguins bill length')
plt.legend()
plt.show()

# %%
sns.histplot(x='bill_depth_mm', kde=True, data=penguins_df,label='bill_depth',color='wheat')
plt.title('Penguins bill depth')
plt.legend()
plt.show()

# %%
sns.histplot(x='flipper_length_mm', kde=True, data=penguins_df,color='green',label='flipper_length')
plt.title('Penguins flipper length')
plt.xlabel('flipper_length')
plt.legend()
plt.show()

# %%
sns.histplot(x='body_mass_g', kde=True, data=penguins_df,color='red',label='body_mass')
plt.title('Penguins body mass')
plt.xlabel('body_mass')
plt.legend()
plt.show()

# %% [markdown]
# ##### The relationship in species, island and sex

# %%
sns.scatterplot(data=penguins_df,x='bill_length_mm',y='bill_depth_mm',hue='species')
plt.title('The relationship of the two features in species')
plt.show()

# %%
sns.scatterplot(data=penguins_df,x='bill_length_mm',y='bill_depth_mm',hue='island')
plt.title('The relationship of the two features in island')
plt.show()

# %%
sns.scatterplot(data=penguins_df,x='bill_length_mm',y='bill_depth_mm',hue='sex')
plt.title('The relationship of the two features in sex')
plt.show()

# %% [markdown]
# ##### The average value of each penguins feature in species , island and sex

# %%
df = pd.melt(gr_species, id_vars="species", var_name="Penguin_body", value_name="average_size")
df
# Out:
#       species       Penguin_body  average_size
# 0      Adelie     bill_length_mm     38.823973
# 1   Chinstrap     bill_length_mm     48.833824
# 2      Gentoo     bill_length_mm     47.568067
# 3      Adelie      bill_depth_mm     18.347260
# 4   Chinstrap      bill_depth_mm     18.420588
# 5      Gentoo      bill_depth_mm     14.996639
# 6      Adelie  flipper_length_mm    190.102740
# 7   Chinstrap  flipper_length_mm    195.823529
# 8      Gentoo  flipper_length_mm    217.235294
# 9      Adelie        body_mass_g   3706.164384
# 10  Chinstrap        body_mass_g   3733.088235
# 11     Gentoo        body_mass_g   5092.436975

# %%
df1 = pd.melt(gr_island, id_vars="island", var_name="Penguin_body", value_name="average_size")
df1
# Out:
#        island       Penguin_body  average_size
# 0      Biscoe     bill_length_mm     45.248466
# 1       Dream     bill_length_mm     44.221951
# 2   Torgersen     bill_length_mm     39.038298
# 3      Biscoe      bill_depth_mm     15.907362
# 4       Dream      bill_depth_mm     18.339837
# 5   Torgersen      bill_depth_mm     18.451064
# 6      Biscoe  flipper_length_mm    209.558282
# 7       Dream  flipper_length_mm    193.186992
# 8   Torgersen  flipper_length_mm    191.531915
# 9      Biscoe        body_mass_g   4719.171779
# 10      Dream        body_mass_g   3718.902439
# 11  Torgersen        body_mass_g   3708.510638

# %%
df2 = pd.melt(gr_sex, id_vars="sex", var_name="Penguin_body", value_name="average_size")
df2
# Out:
#       sex       Penguin_body  average_size
# 0  Female     bill_length_mm     42.096970
# 1    Male     bill_length_mm     45.854762
# 2  Female      bill_depth_mm     16.425455
# 3    Male      bill_depth_mm     17.891071
# 4  Female  flipper_length_mm    197.363636
# 5    Male  flipper_length_mm    204.505952
# 6  Female        body_mass_g   3862.272727
# 7    Male        body_mass_g   4545.684524

# %%
sns.factorplot(x='species', y='average_size', hue='Penguin_body', data=df, kind='bar')
plt.title('The average value of each penguins feature in species')
plt.show()
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='island', y='average_size', hue='Penguin_body', data=df1, kind='bar')
plt.title('The average value of each penguins feature in island')
plt.show()
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='sex', y='average_size', hue='Penguin_body', data=df2, kind='bar')
plt.title('The average value of each penguins feature in sex')
plt.show()
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ## BOX PLOT

# %%
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.boxplot(x='species',y='bill_length_mm',hue='species', data=penguins_df)
plt.title('Penguins feature in bill_length')
plt.show()

# %%
sns.boxplot(x='species',y='bill_depth_mm',hue='species', data=penguins_df)
plt.title('Penguins feature in bill_depth')
plt.show()

# %%
sns.boxplot(x='species',y='flipper_length_mm',hue='species', data=penguins_df)
plt.title('Penguins feature in flipper_length')
plt.show()

# %%
sns.boxplot(x='species',y='body_mass_g',hue='species', data=penguins_df)
plt.title('Penguins feature in body_mass')
plt.show()

# %% [markdown]
# ## VIOLIN PLOT

# %%
sns.violinplot(x='sex', y='bill_length_mm', data=penguins_df,hue='sex')
plt.title('Penguins feature in bill_length with sex')
plt.show()

# %%
sns.violinplot(x='sex', y='bill_depth_mm', data=penguins_df,hue='sex')
plt.title('Penguins feature in bill_depth with sex')
plt.show()

# %%
sns.violinplot(x='sex', y='flipper_length_mm', data=penguins_df,hue='sex')
plt.title('Penguins feature in flipper_length with sex')
plt.show()

# %%
sns.violinplot(x='sex', y='body_mass_g', data=penguins_df,hue='sex')
plt.title('Penguins feature in body_mass with sex')
plt.show()
